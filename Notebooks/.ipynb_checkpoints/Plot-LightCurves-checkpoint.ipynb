# %%
import os, gc, itertools
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.manifold import TSNE

from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
gc.collect()
#read csv
training = pd.read_csv('../Train-Data/training_set.csv')
meta_training = pd.read_csv('../Train-Data/training_set_metadata.csv')
print ('check shapes: ', training.shape, meta_training.shape)
print (training.head(5))
meta_training.head(5)
# Out:
# check shapes:  (1421705, 6) (7848, 12)
#    object_id         mjd  passband        flux   flux_err  detected
# 0        615  59750.4229         2 -544.810303   3.622952         1
# 1        615  59750.4306         1 -816.434326   5.553370         1
# 2        615  59750.4383         3 -471.385529   3.801213         1
# 3        615  59750.4450         4 -388.984985  11.395031         1
# 4        615  59752.4070         2 -681.858887   4.041204         1
#    object_id          ra       decl       gal_l      gal_b  ddf  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706    1
# 1        713   53.085938 -27.784405  223.525509 -54.460748    1
# 2        730   33.574219  -6.579593  170.455585 -61.548219    1
# 3        745    0.189873 -45.586655  328.254458 -68.969298    1
# 4       1124  352.711273 -63.823658  316.922299 -51.059403    1
#
#    hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# ...

# %%
my_map = {0:'u', 1:'g', 2:'r', 3:'i', 4:'z', 5:'y'}
training['passband_n'] = training['passband'].map(my_map)
training.head(5)
# Out:
#    object_id         mjd  passband        flux   flux_err  detected passband_n
# 0        615  59750.4229         2 -544.810303   3.622952         1          r
# 1        615  59750.4306         1 -816.434326   5.553370         1          g
# 2        615  59750.4383         3 -471.385529   3.801213         1          i
# 3        615  59750.4450         4 -388.984985  11.395031         1          z
# 4        615  59752.4070         2 -681.858887   4.041204         1          r

# %%
## merge the flux data set based on object ids
merged = training.merge(meta_training, on = "object_id")
merged = merged.sort_values(by='object_id', ascending=True)
print ('check the shape of the merged dataframe: ', merged.shape)
merged.head(5)
# Out:
# check the shape of the merged dataframe:  (1421705, 18)
#      object_id         mjd  passband         flux  flux_err  detected  \
# 0          615  59750.4229         2  -544.810303  3.622952         1
# 239        615  60493.2639         4  -406.733521  3.772714         1
# 238        615  60493.2527         3  -530.644592  3.672556         1
# 237        615  60493.2450         1 -1031.102905  6.378702         1
# 236        615  60493.2372         2  -680.489441  4.065931         1
#
#     passband_n          ra       decl      gal_l      gal_b  ddf  \
# 0            r  349.046051 -61.943836  320.79653 -51.753706    1
# 239          z  349.046051 -61.943836  320.79653 -51.753706    1
# 238          i  349.046051 -61.943836  320.79653 -51.753706    1
# 237          g  349.046051 -61.943836  320.79653 -51.753706    1
# 236          r  349.046051 -61.943836  320.79653 -51.753706    1
#
#      hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# ...

# %% [markdown]
# ### Example of Data Collection Period

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sns.histplot(merged[merged['object_id'] == 615]['mjd'], ax=axs[0], bins=200)
axs[0].set_title('Object id: 615, Target: 92')
sns.histplot(merged[merged['object_id'] == 713]['mjd'], ax=axs[1], bins=200)
axs[1].set_title('Object id: 713, Target: 88')
# Out:
# Text(0.5, 1.0, 'Object id: 713, Target: 88')

# %% [markdown]
# ###### Note from plot above:  Irregular Time Series with Gaps

# %% [markdown]
# #### Plotting Light Curves (Specific Object within a Source Class)

# %%
### group objects based on pass band and object id 

groups_obj_pb = training.groupby(['object_id', 'passband'])



times = groups_obj_pb.apply(lambda block: block['mjd'].values).reset_index().rename(columns={0: 'seq'})
print (times.head(3))

print ('\n')

object_list_grpby=times.groupby('object_id').apply(lambda x: x['object_id'].unique()[0]).tolist()
print (len(object_list_grpby), object_list_grpby[5:10])
# Out:
#    object_id  passband                                                seq
# 0        615         0  [59819.1532, 59820.1047, 59821.1026, 59822.110...
# 1        615         1  [59750.4306, 59752.4147, 59767.3045, 59770.225...
# 2        615         2  [59750.4229, 59752.407, 59767.2968, 59770.2179...
#
#
# 7848 [1227, 1598, 1632, 1920, 1926]

# %%
### setting up the plotting routine 


colors_6_list = ['violet', 'green', 'red', 'indigo', 'darkslategray', 'yellow']

def plot_one_object(df, grpd_obj, cat, obj_id, split=False, frequency=0):
    
    if split:
        fig, axes = plt.subplots(2, 3, sharex=True, sharey=False, figsize=(12, 8))
    else:
        fig, ax=plt.subplots(figsize=(10, 6))
    for band in range(len(colors_6_list)):
        if split:
            ax = axes[band // 3, band % 3]
        sample = df[(df['object_id'] == grpd_obj) & (df['passband']==band)]
        if frequency:
            phase=(sample['mjd'] * frequency ) % 1
        else:
            phase=sample['mjd']
        ax.errorbar(x=phase,y=sample['flux'], yerr=sample['flux_err'], 
                    c = colors_6_list[band],fmt='o',alpha=0.7, label='%d'%(band))
        ax.set_xlabel('mjd', fontsize=13)
        ax.set_ylabel('Flux', fontsize=13)
        ax.set_title('Category: %d, Obj_Id: %d'%(cat, obj_id))
        ax.legend(fontsize=10, loc='best')

# %%
category = 6 # assumed to be microlensing events (from other papers)

iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==1)]['object_id'].index[2]
# ddf: A Boolean flag to identify the object as coming from the DDF survey area 
# the DDF fields have significantly smaller uncertainties
print ('check what is iobj: ', iobj)
print ('check what iobj points to: ', object_list_grpby[iobj])
## call the plotting routine created above
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# check what is iobj:  491
# check what iobj points to:  83348

# %%
category = 15 #sn type 2? 
iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==1)]['object_id'].index[3]
print (iobj)
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# 684

# %%
category = 52
iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==0)]['object_id'].index[2]
print (iobj)
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# 2326

# %%
category = 64
iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==0)]['object_id'].index[3]
print (iobj)
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# 2265

# %%
category = 88 # variability over a time AGN ? Variable star? 
iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==1)]['object_id'].index[4]
print (iobj)
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# 38

# %%
category = 90
iobj=meta_training[(meta_training['target']==category) & (meta_training['ddf']==0)]['object_id'].index[3]
print (iobj)
plot_one_object(training, grpd_obj=object_list_grpby[iobj], cat=category, obj_id=iobj, split=False)
# Out:
# 2124
